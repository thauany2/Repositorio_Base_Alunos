# %%
### pegar a nota da prova teórica
### pedir para o usuario
### calcular a média
### como eu calculo a média?? se você vc n souber ja reprovou
### se a média for maior ou igual a 7 , print("aprovado")
### se não, reprovado
nota_teorica = float(input("digite sua nota na teórica ?:")) 
nota_pratica = float(input("qual é a sua nota na prática?:"))
media = nota_teorica + nota_pratica / 2

if media >=7:
    print("Parabéns você passou !!😀 ")
elif media < 7:
    print(" Você foi reprovado 🚨")
# Out:
# Parabéns você passou !!😀

# %% [markdown]
# ### playlist do alejandro

# %%
### perguntar a quantidade de música a ser adicionada na playlist
### pergunte o nome do artista e o nome da música
### depois de adicionar a listas, de um print mostrando os artistas e as músicas
### Se na lista tiver pablo vittar , print("Alejandro curte")

playlist = ["Blinding Lights - The Weeknd", "Flowers - Miley Cyrus", "As It Was - Harry Styles"]
musica = input("Sua música favorita ?")

playlist.append(musica)
playlist.sort()
print(f"Total de músicas: {len(playlist)}")
print("\n🎵 PLAYLIST ATUALIZADA 🎵")
for musica in playlist:
     print(f"🎧 {musica}")
# Out:
# Total de músicas: 4
#
# 🎵 PLAYLIST ATUALIZADA 🎵
# 🎧 As It Was - Harry Styles
# 🎧 Blinding Lights - The Weeknd
# 🎧 Flowers - Miley Cyrus
# 🎧 controle - anny
